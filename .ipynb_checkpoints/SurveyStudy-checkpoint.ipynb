# %% [markdown]
# ## Luke Traverso
# ## Professor Binowski
# ## 10.2.24
# ### Results of the Fall 2024 Study
# ### Sort through the CSV file, get the information and clean up data

# %%
import pandas as pd
survey = pd.read_csv('Majors Survey Results - Fall 2024.csv')

# %% [markdown]
# ## Learn about the CSV, what is in the dataframe and how it is formatted

# %%
survey.head()

# %%
survey.tail()

# %%
survey.info()

# %%
survey.columns

# %%
survey.describe()

# %%
survey.dtypes

# %%
survey.sample()

# %% [markdown]
# ## Make the df more digestible and shorten the columns

# %%
survey1 = survey.rename(columns={
    'Which course are you enrolled in?': 'course_enrolled',
    'How did you hear about County College of Morris? [CCM Web site]': 'source_ccm_website',
    'How did you hear about County College of Morris? [Social Media]':'source_socialmedia',
    'How did you hear about County College of Morris? [Community Event]':'source_communityevent',
    'How did you hear about County College of Morris? [Family member or friend]':'source_family_friend',
    'How did you hear about County College of Morris? [Current CCM student]':'source_currentccm_student',
    'How did you hear about County College of Morris? [CCM Alumni]':'source_ccm_alumni',
    'How did you hear about County College of Morris? [High School Teacher]':'source_hs_teacher',
    'How did you hear about County College of Morris? [High School Counselor]':'source_hs_counselor',
    'How did you hear about County College of Morris? [In-app advertisement]':'source_in-app_ad',
    'Race/ethnicity': 'race_ethnicity',
    'Gender':'gender',
    'Age': 'age',
    'Major': 'major'
}).drop(columns=['Timestamp'])

# %%
survey1.head()

# %%
survey1.tail()

# %%
survey1.replace({'race_ethnicity': {'Hispanic or Latino': 'Hispanic/Latino'}}, inplace=True)
survey1.tail()
# Out:
#                                   course_enrolled source_ccm_website  \
# 192                    CMP 128 Computer Science I       Don't recall
# 193                    CMP 128 Computer Science I                Yes
# 194                    CMP 128 Computer Science I                Yes
# 195                    CMP 128 Computer Science I                Yes
# 196  CMP 131 Fundamentals of Programming (Python)                 No
#
#     source_socialmedia source_communityevent source_family_friend  \
# 192       Don't recall          Don't recall         Don't recall
# 193                 No                    No                  Yes
# 194       Don't recall                    No                   No
# 195                 No                    No                  Yes
# 196                 No                    No                  Yes
#
#     source_currentccm_student source_ccm_alumni source_hs_teacher  \
# 192                       Yes      Don't recall      Don't recall
# ...

# %%
survey1.columns

# %%
# Dictionary mapping of old column names to new shorter names
new_column_names = {
    'How did you hear about County College of Morris? [Employer]': 'source_employer',
    'How did you hear about County College of Morris? [Billboard]': 'source_billboard',
    'How did you hear about County College of Morris? [Television]': 'source_television',
    'How did you hear about County College of Morris? [Radio]': 'source_radio',
    'How did you hear about County College of Morris? [Other]': 'source_other',

    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'impact_cost',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'impact_location',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'impact_program_choice',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'impact_online_offerings',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'impact_family_friend',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'impact_faculty_staff',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'impact_reputation',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'impact_fin_aid',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'impact_scholarships',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'impact_class_size',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'impact_extracurricular',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'impact_transfer_credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'impact_neg_exp_other_college',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'impact_nj_stars',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'impact_transfer_ccm_credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'impact_hs_college_credit',

     # Events prior to applying
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'participation_regional_fair',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'participation_hs_sharetime',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'participation_challenger',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'participation_cybersecurity',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'participation_hs_info',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'participation_hs_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'participation_indiv_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'participation_workforce_dev',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'participation_corp_training',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': 'participation_teen_arts',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': 'participation_summer_camp',

    # Participation in events
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'participation_open_house',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'participation_decision_day',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'participation_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]': 'participation_titans_tuesday',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'participation_women_dare',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]': 'impact_hs_computing_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]': 'impact_hs_computing_club',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]': 'impact_computing_competition',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]': 'impact_afterschool_program',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]': 'impact_summer_program',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]': 'impact_ap_computing',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]': 'impact_dual_enrollment',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]': 'impact_family_friend_influence',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]': 'impact_family_computing_field',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]': 'impact_hs_teacher_counselor',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]': 'impact_employer_influence',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]': 'impact_current_student',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]': 'impact_work_experience',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]': 'impact_other',

    # Motivation for computing
    'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]': 'motivation_computing_job',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor\'s level program]': 'motivation_transfer_bachelors',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]': 'motivation_career_advancement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]': 'motivation_career_change',
    'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]': 'motivation_professional_dev',
    'What degree program are you currently enrolled in?': 'current_program',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]': 'motivation_transfer_hs_credits',
    'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]': 'motivation_job_displacement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]': 'motivation_relocation',
    'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]': 'motivation_current_tech',
    'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]': 'motivation_it_certifications',
    'What motivated you to seek a computing degree/certificate at CCM?  [Financial]': 'motivation_financial',
    'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]': 'motivation_enrichment'
}

# Rename columns
survey1.rename(columns=new_column_names, inplace=True)
#I got this code from chat gpt to automate the renaming of the columns to make everything much easier nad not have to manually input so many long column names

# %%
#check all the column names
survey1.columns
# Out:
# Index(['course_enrolled', 'source_ccm_website', 'source_socialmedia',
#        'source_communityevent', 'source_family_friend',
#        'source_currentccm_student', 'source_ccm_alumni', 'source_hs_teacher',
#        'source_hs_counselor', 'source_in-app_ad', 'source_employer',
#        'source_billboard', 'source_television', 'source_radio', 'source_other',
#        'impact_cost', 'impact_location', 'impact_program_choice',
#        'impact_online_offerings', 'impact_family_friend',
#        'impact_faculty_staff', 'impact_reputation', 'impact_fin_aid',
#        'impact_scholarships', 'impact_class_size', 'impact_extracurricular',
#        'impact_transfer_credits', 'impact_neg_exp_other_college',
#        'impact_nj_stars', 'impact_transfer_ccm_credits',
#        'impact_hs_college_credit', 'participation_open_house',
#        'participation_decision_day', 'participation_info_session',
#        'participation_titans_tuesday', 'participation_women_dare',
# ...

# %%
##just wanted to have it be a better name
cleansurvey = survey1

# %%
##display to make sure it was done correctly
cleansurvey
# Out:
#                                   course_enrolled source_ccm_website  \
# 0                      CMP 128 Computer Science I                Yes
# 1                                             NaN                 No
# 2                      CMP 128 Computer Science I                 No
# 3                      CMP 128 Computer Science I                Yes
# 4                      CMP 128 Computer Science I                 No
# ..                                            ...                ...
# 192                    CMP 128 Computer Science I       Don't recall
# 193                    CMP 128 Computer Science I                Yes
# 194                    CMP 128 Computer Science I                Yes
# 195                    CMP 128 Computer Science I                Yes
# 196  CMP 131 Fundamentals of Programming (Python)                 No
#
#     source_socialmedia source_communityevent source_family_friend  \
# 0                  Yes                   Yes                  Yes
# ...

# %% [markdown]
# ## Save to a new csv file

# %%
cleansurvey.to_csv('cleansurvey.csv', index=False)
